# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px
import plotly.graph_objects as go

# %%
# Read in clean dataset from previous step
df = pd.read_parquet("../data/processed/ads_clean.parquet")
